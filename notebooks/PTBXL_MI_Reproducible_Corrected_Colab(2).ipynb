# %% [markdown]
# # Reproducible PTB-XL MI Prediction Notebook
#
# This notebook is designed to match the paper:
#
# **A Lightweight Agentic Framework for Interpretable ECG-Based Myocardial Infarction Prediction on PTB-XL: Bridging the Translational Gap**
#
# It includes:
#
# 1. Robust PTB-XL download/loading for Google Colab
# 2. SCP-to-MI label mapping
# 3. Official PTB-XL split: folds 1–8 train, fold 9 validation, fold 10 test
# 4. Train-only Z-score normalization
# 5. Lightweight 1D CNN
# 6. `BCEWithLogitsLoss` training
# 7. Best-validation-checkpoint selection
# 8. Fold-10 AUROC/AUPRC evaluation
# 9. ROC/PR curve generation
# 10. Deterministic risk-summary workflow
#
# **Important:** After running the notebook, update the paper with the exact AUROC/AUPRC values printed by this notebook.

# %% [markdown]
# ## 1. Install dependencies

# %%
# In Colab this installs the required packages.
# If you are running locally and already have these packages, you can skip this cell.
# !pip -q install wfdb scikit-learn pandas numpy matplotlib torch torchvision tqdm requests
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 2.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.9/163.9 kB 6.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 31.5 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 3.0.3 which is incompatible.
# bqplot 0.12.45 requires pandas<3.0.0,>=1.0.0, but you have pandas 3.0.3 which is incompatible.
# db-dtypes 1.5.1 requires pandas<3.0.0,>=1.5.3, but you have pandas 3.0.3 which is incompatible.
# gradio 5.50.0 requires pandas<3.0,>=1.0, but you have pandas 3.0.3 which is incompatible.

# %% [markdown]
# ## 2. Imports and reproducibility settings

# %%
import os
import ast
import random
from pathlib import Path

import numpy as np
import pandas as pd
import wfdb
from tqdm.auto import tqdm

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader

from sklearn.metrics import (
    roc_auc_score,
    average_precision_score,
    roc_curve,
    precision_recall_curve,
    confusion_matrix,
    classification_report,
)

import matplotlib.pyplot as plt

SEED = 42

def set_seed(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)

    # Deterministic settings improve reproducibility but can slow training.
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

set_seed(SEED)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Device:", device)
# Out:
# Device: cpu

# %% [markdown]
# ## 3. Configure project directory

# %%
# This cell is safe for Colab and local execution.
# In Colab, Google Drive is strongly recommended because PTB-XL is large.

USE_GOOGLE_DRIVE = True  # Set to False if you want to use local /content storage in Colab.

IN_COLAB = False
try:
    import google.colab
    IN_COLAB = True
except Exception:
    IN_COLAB = False

if IN_COLAB and USE_GOOGLE_DRIVE:
    from google.colab import drive
    drive.mount("/content/drive")
    PROJECT_DIR = Path("/content/drive/MyDrive/ptbxl_mi_project")
elif IN_COLAB:
    PROJECT_DIR = Path("/content/ptbxl_mi_project")
else:
    PROJECT_DIR = Path("./ptbxl_mi_project")

DATA_DIR = PROJECT_DIR / "ptbxl"
OUTPUT_DIR = PROJECT_DIR / "outputs"

DATA_DIR.mkdir(parents=True, exist_ok=True)
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

metadata_path = DATA_DIR / "ptbxl_database.csv"
scp_path = DATA_DIR / "scp_statements.csv"

print("IN_COLAB:", IN_COLAB)
print("PROJECT_DIR:", PROJECT_DIR)
print("DATA_DIR:", DATA_DIR)
print("OUTPUT_DIR:", OUTPUT_DIR)
print("metadata_path:", metadata_path)
print("scp_path:", scp_path)
# Out:
# Mounted at /content/drive
# IN_COLAB: True
# PROJECT_DIR: /content/drive/MyDrive/ptbxl_mi_project
# DATA_DIR: /content/drive/MyDrive/ptbxl_mi_project/ptbxl
# OUTPUT_DIR: /content/drive/MyDrive/ptbxl_mi_project/outputs
# metadata_path: /content/drive/MyDrive/ptbxl_mi_project/ptbxl/ptbxl_database.csv
# scp_path: /content/drive/MyDrive/ptbxl_mi_project/ptbxl/scp_statements.csv

# %% [markdown]
# ## 4. Download PTB-XL metadata and 100 Hz records

# %%
# This cell avoids wfdb.dl_database(), which can fail when PhysioNet gives temporary 502 errors.
# It downloads only the 100 Hz ECG files used in the paper: records100/.
#
# If the download stops or Colab disconnects, run this same cell again.
# Because wget uses -c and -N, it will resume/skip already downloaded files.

BASE_URL = "https://physionet.org/files/ptb-xl/1.0.3"

print("Downloading metadata files...")
# !wget -c --tries=50 --waitretry=20 --retry-connrefused --read-timeout=60 --timeout=30 \
  -O "{metadata_path}" "{BASE_URL}/ptbxl_database.csv"

# !wget -c --tries=50 --waitretry=20 --retry-connrefused --read-timeout=60 --timeout=30 \
  -O "{scp_path}" "{BASE_URL}/scp_statements.csv"

print("Downloading/resuming records100 directory...")
# !wget -r -N -c -np -nH --cut-dirs=3 \
  --tries=50 \
  --waitretry=20 \
  --retry-connrefused \
  --read-timeout=60 \
  --timeout=30 \
  --no-check-certificate \
  -R "index.html*" \
  -P "{DATA_DIR}" \
  "{BASE_URL}/records100/"

print("Metadata exists:", metadata_path.exists(), metadata_path)
print("SCP exists:", scp_path.exists(), scp_path)

assert metadata_path.exists(), f"Missing {metadata_path}"
assert scp_path.exists(), f"Missing {scp_path}"

print("Download/check cell finished.")
# Out:
# Streaming output truncated to the last 5000 lines.
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 600 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21587_lr.hea’
#
# records100/21000/21 100%[===================>]     600  --.-KB/s    in 0s
#
# 2026-05-16 17:42:06 (65.8 MB/s) - ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21587_lr.hea’ saved [600/600]
#
# --2026-05-16 17:42:06--  https://physionet.org/files/ptb-xl/1.0.3/records100/21000/21588_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21588_lr.dat’
#
# records100/21000/21 100%[===================>]  23.44K  --.-KB/s    in 0.05s
#
# 2026-05-16 17:42:06 (484 KB/s) - ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21588_lr.dat’ saved [24000/24000]
#
# --2026-05-16 17:42:06--  https://physionet.org/files/ptb-xl/1.0.3/records100/21000/21588_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 606 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21588_lr.hea’
#
# records100/21000/21 100%[===================>]     606  --.-KB/s    in 0s
#
# 2026-05-16 17:42:06 (72.1 MB/s) - ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21588_lr.hea’ saved [606/606]
#
# --2026-05-16 17:42:06--  https://physionet.org/files/ptb-xl/1.0.3/records100/21000/21589_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21589_lr.dat’
#
# records100/21000/21 100%[===================>]  23.44K  --.-KB/s    in 0.004s
#
# 2026-05-16 17:42:07 (5.30 MB/s) - ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21589_lr.dat’ saved [24000/24000]
#
# --2026-05-16 17:42:07--  https://physionet.org/files/ptb-xl/1.0.3/records100/21000/21589_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 604 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21589_lr.hea’
#
# records100/21000/21 100%[===================>]     604  --.-KB/s    in 0s
#
# 2026-05-16 17:42:07 (72.5 MB/s) - ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21589_lr.hea’ saved [604/604]
#
# --2026-05-16 17:42:07--  https://physionet.org/files/ptb-xl/1.0.3/records100/21000/21590_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21590_lr.dat’
#
# records100/21000/21 100%[===================>]  23.44K  --.-KB/s    in 0.04s
#
# 2026-05-16 17:42:07 (565 KB/s) - ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21590_lr.dat’ saved [24000/24000]
#
# --2026-05-16 17:42:07--  https://physionet.org/files/ptb-xl/1.0.3/records100/21000/21590_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 602 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21590_lr.hea’
#
# records100/21000/21 100%[===================>]     602  --.-KB/s    in 0s
#
# 2026-05-16 17:42:07 (74.4 MB/s) - ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21590_lr.hea’ saved [602/602]
#
# --2026-05-16 17:42:07--  https://physionet.org/files/ptb-xl/1.0.3/records100/21000/21591_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21591_lr.dat’
#
# records100/21000/21 100%[===================>]  23.44K  --.-KB/s    in 0.05s
#
# 2026-05-16 17:42:08 (479 KB/s) - ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21591_lr.dat’ saved [24000/24000]
#
# --2026-05-16 17:42:08--  https://physionet.org/files/ptb-xl/1.0.3/records100/21000/21591_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 502 Bad Gateway
# 2026-05-16 17:42:08 ERROR 502: Bad Gateway.
#
# --2026-05-16 17:42:08--  https://physionet.org/files/ptb-xl/1.0.3/records100/21000/21592_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21592_lr.dat’
#
# records100/21000/21 100%[===================>]  23.44K  --.-KB/s    in 0.05s
#
# 2026-05-16 17:42:09 (477 KB/s) - ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21592_lr.dat’ saved [24000/24000]
#
# --2026-05-16 17:42:09--  https://physionet.org/files/ptb-xl/1.0.3/records100/21000/21592_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 604 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21592_lr.hea’
#
# records100/21000/21 100%[===================>]     604  --.-KB/s    in 0s
#
# 2026-05-16 17:42:09 (63.7 MB/s) - ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21592_lr.hea’ saved [604/604]
#
# --2026-05-16 17:42:09--  https://physionet.org/files/ptb-xl/1.0.3/records100/21000/21593_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21593_lr.dat’
#
# records100/21000/21 100%[===================>]  23.44K  --.-KB/s    in 0.003s
#
# 2026-05-16 17:42:10 (6.64 MB/s) - ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21593_lr.dat’ saved [24000/24000]
#
# --2026-05-16 17:42:10--  https://physionet.org/files/ptb-xl/1.0.3/records100/21000/21593_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 603 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21593_lr.hea’
#
# records100/21000/21 100%[===================>]     603  --.-KB/s    in 0s
#
# 2026-05-16 17:42:10 (82.9 MB/s) - ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21593_lr.hea’ saved [603/603]
#
# --2026-05-16 17:42:10--  https://physionet.org/files/ptb-xl/1.0.3/records100/21000/21594_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21594_lr.dat’
#
# records100/21000/21 100%[===================>]  23.44K  --.-KB/s    in 0.05s
#
# 2026-05-16 17:42:10 (469 KB/s) - ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21594_lr.dat’ saved [24000/24000]
#
# --2026-05-16 17:42:10--  https://physionet.org/files/ptb-xl/1.0.3/records100/21000/21594_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 604 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21594_lr.hea’
#
# records100/21000/21 100%[===================>]     604  --.-KB/s    in 0s
#
# 2026-05-16 17:42:11 (70.7 MB/s) - ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21594_lr.hea’ saved [604/604]
#
# --2026-05-16 17:42:11--  https://physionet.org/files/ptb-xl/1.0.3/records100/21000/21595_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21595_lr.dat’
#
# records100/21000/21 100%[===================>]  23.44K  --.-KB/s    in 0.04s
#
# 2026-05-16 17:42:11 (583 KB/s) - ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21595_lr.dat’ saved [24000/24000]
#
# --2026-05-16 17:42:11--  https://physionet.org/files/ptb-xl/1.0.3/records100/21000/21595_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 502 Bad Gateway
# 2026-05-16 17:42:11 ERROR 502: Bad Gateway.
#
# --2026-05-16 17:42:11--  https://physionet.org/files/ptb-xl/1.0.3/records100/21000/21596_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21596_lr.dat’
#
# records100/21000/21 100%[===================>]  23.44K  --.-KB/s    in 0.04s
#
# 2026-05-16 17:42:12 (573 KB/s) - ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21596_lr.dat’ saved [24000/24000]
#
# --2026-05-16 17:42:12--  https://physionet.org/files/ptb-xl/1.0.3/records100/21000/21596_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 598 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21596_lr.hea’
#
# records100/21000/21 100%[===================>]     598  --.-KB/s    in 0s
#
# 2026-05-16 17:42:12 (75.0 MB/s) - ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21596_lr.hea’ saved [598/598]
#
# --2026-05-16 17:42:12--  https://physionet.org/files/ptb-xl/1.0.3/records100/21000/21597_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21597_lr.dat’
#
# records100/21000/21 100%[===================>]  23.44K  --.-KB/s    in 0.03s
#
# 2026-05-16 17:42:12 (829 KB/s) - ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21597_lr.dat’ saved [24000/24000]
#
# --2026-05-16 17:42:12--  https://physionet.org/files/ptb-xl/1.0.3/records100/21000/21597_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 598 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21597_lr.hea’
#
# records100/21000/21 100%[===================>]     598  --.-KB/s    in 0s
#
# 2026-05-16 17:42:13 (73.4 MB/s) - ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21597_lr.hea’ saved [598/598]
#
# --2026-05-16 17:42:13--  https://physionet.org/files/ptb-xl/1.0.3/records100/21000/21598_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21598_lr.dat’
#
# records100/21000/21 100%[===================>]  23.44K   113KB/s    in 0.2s
#
# 2026-05-16 17:42:13 (113 KB/s) - ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21598_lr.dat’ saved [24000/24000]
#
# --2026-05-16 17:42:13--  https://physionet.org/files/ptb-xl/1.0.3/records100/21000/21598_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 608 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21598_lr.hea’
#
# records100/21000/21 100%[===================>]     608  --.-KB/s    in 0s
#
# 2026-05-16 17:42:13 (59.6 MB/s) - ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21598_lr.hea’ saved [608/608]
#
# --2026-05-16 17:42:13--  https://physionet.org/files/ptb-xl/1.0.3/records100/21000/21599_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21599_lr.dat’
#
# records100/21000/21 100%[===================>]  23.44K  --.-KB/s    in 0.06s
#
# 2026-05-16 17:42:13 (420 KB/s) - ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21599_lr.dat’ saved [24000/24000]
#
# --2026-05-16 17:42:13--  https://physionet.org/files/ptb-xl/1.0.3/records100/21000/21599_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 612 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21599_lr.hea’
#
# records100/21000/21 100%[===================>]     612  --.-KB/s    in 0s
#
# 2026-05-16 17:42:14 (72.5 MB/s) - ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21599_lr.hea’ saved [612/612]
#
# --2026-05-16 17:42:14--  https://physionet.org/files/ptb-xl/1.0.3/records100/21000/21600_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21600_lr.dat’
#
# records100/21000/21 100%[===================>]  23.44K  --.-KB/s    in 0.04s
#
# 2026-05-16 17:42:14 (540 KB/s) - ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21600_lr.dat’ saved [24000/24000]
#
# --2026-05-16 17:42:14--  https://physionet.org/files/ptb-xl/1.0.3/records100/21000/21600_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 605 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21600_lr.hea’
#
# records100/21000/21 100%[===================>]     605  --.-KB/s    in 0s
#
# 2026-05-16 17:42:14 (65.0 MB/s) - ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21600_lr.hea’ saved [605/605]
#
# --2026-05-16 17:42:14--  https://physionet.org/files/ptb-xl/1.0.3/records100/21000/21601_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21601_lr.dat’
#
# records100/21000/21 100%[===================>]  23.44K  --.-KB/s    in 0.05s
#
# 2026-05-16 17:42:14 (478 KB/s) - ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21601_lr.dat’ saved [24000/24000]
#
# --2026-05-16 17:42:14--  https://physionet.org/files/ptb-xl/1.0.3/records100/21000/21601_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 597 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21601_lr.hea’
#
# records100/21000/21 100%[===================>]     597  --.-KB/s    in 0s
#
# 2026-05-16 17:42:15 (75.7 MB/s) - ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21601_lr.hea’ saved [597/597]
#
# --2026-05-16 17:42:15--  https://physionet.org/files/ptb-xl/1.0.3/records100/21000/21602_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21602_lr.dat’
#
# records100/21000/21 100%[===================>]  23.44K  --.-KB/s    in 0.05s
#
# 2026-05-16 17:42:15 (510 KB/s) - ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21602_lr.dat’ saved [24000/24000]
#
# --2026-05-16 17:42:15--  https://physionet.org/files/ptb-xl/1.0.3/records100/21000/21602_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 609 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21602_lr.hea’
#
# records100/21000/21 100%[===================>]     609  --.-KB/s    in 0s
#
# 2026-05-16 17:42:15 (70.9 MB/s) - ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21602_lr.hea’ saved [609/609]
#
# --2026-05-16 17:42:15--  https://physionet.org/files/ptb-xl/1.0.3/records100/21000/21603_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21603_lr.dat’
#
# records100/21000/21 100%[===================>]  23.44K  --.-KB/s    in 0.05s
#
# 2026-05-16 17:42:15 (432 KB/s) - ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21603_lr.dat’ saved [24000/24000]
#
# --2026-05-16 17:42:15--  https://physionet.org/files/ptb-xl/1.0.3/records100/21000/21603_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 599 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21603_lr.hea’
#
# records100/21000/21 100%[===================>]     599  --.-KB/s    in 0s
#
# 2026-05-16 17:42:16 (74.6 MB/s) - ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21603_lr.hea’ saved [599/599]
#
# --2026-05-16 17:42:16--  https://physionet.org/files/ptb-xl/1.0.3/records100/21000/21604_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21604_lr.dat’
#
# records100/21000/21 100%[===================>]  23.44K  --.-KB/s    in 0.05s
#
# 2026-05-16 17:42:16 (455 KB/s) - ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21604_lr.dat’ saved [24000/24000]
#
# --2026-05-16 17:42:16--  https://physionet.org/files/ptb-xl/1.0.3/records100/21000/21604_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 598 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21604_lr.hea’
#
# records100/21000/21 100%[===================>]     598  --.-KB/s    in 0s
#
# 2026-05-16 17:42:16 (67.2 MB/s) - ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21604_lr.hea’ saved [598/598]
#
# --2026-05-16 17:42:16--  https://physionet.org/files/ptb-xl/1.0.3/records100/21000/21605_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21605_lr.dat’
#
# records100/21000/21 100%[===================>]  23.44K  --.-KB/s    in 0.04s
#
# 2026-05-16 17:42:16 (536 KB/s) - ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21605_lr.dat’ saved [24000/24000]
#
# --2026-05-16 17:42:16--  https://physionet.org/files/ptb-xl/1.0.3/records100/21000/21605_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 604 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21605_lr.hea’
#
# records100/21000/21 100%[===================>]     604  --.-KB/s    in 0s
#
# 2026-05-16 17:42:17 (29.2 MB/s) - ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21605_lr.hea’ saved [604/604]
#
# --2026-05-16 17:42:17--  https://physionet.org/files/ptb-xl/1.0.3/records100/21000/21606_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21606_lr.dat’
#
# records100/21000/21 100%[===================>]  23.44K  --.-KB/s    in 0.03s
#
# 2026-05-16 17:42:17 (774 KB/s) - ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21606_lr.dat’ saved [24000/24000]
#
# --2026-05-16 17:42:17--  https://physionet.org/files/ptb-xl/1.0.3/records100/21000/21606_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 608 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21606_lr.hea’
#
# records100/21000/21 100%[===================>]     608  --.-KB/s    in 0s
#
# 2026-05-16 17:42:17 (77.0 MB/s) - ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21606_lr.hea’ saved [608/608]
#
# --2026-05-16 17:42:17--  https://physionet.org/files/ptb-xl/1.0.3/records100/21000/21607_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21607_lr.dat’
#
# records100/21000/21 100%[===================>]  23.44K  --.-KB/s    in 0.04s
#
# 2026-05-16 17:42:18 (661 KB/s) - ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21607_lr.dat’ saved [24000/24000]
#
# --2026-05-16 17:42:18--  https://physionet.org/files/ptb-xl/1.0.3/records100/21000/21607_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 610 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21607_lr.hea’
#
# records100/21000/21 100%[===================>]     610  --.-KB/s    in 0s
#
# 2026-05-16 17:42:18 (69.8 MB/s) - ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21607_lr.hea’ saved [610/610]
#
# --2026-05-16 17:42:18--  https://physionet.org/files/ptb-xl/1.0.3/records100/21000/21608_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21608_lr.dat’
#
# records100/21000/21 100%[===================>]  23.44K  --.-KB/s    in 0.05s
#
# 2026-05-16 17:42:18 (518 KB/s) - ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21608_lr.dat’ saved [24000/24000]
#
# --2026-05-16 17:42:18--  https://physionet.org/files/ptb-xl/1.0.3/records100/21000/21608_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 502 Bad Gateway
# 2026-05-16 17:42:18 ERROR 502: Bad Gateway.
#
# --2026-05-16 17:42:18--  https://physionet.org/files/ptb-xl/1.0.3/records100/21000/21609_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21609_lr.dat’
#
# records100/21000/21 100%[===================>]  23.44K  --.-KB/s    in 0.03s
#
# 2026-05-16 17:42:19 (750 KB/s) - ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21609_lr.dat’ saved [24000/24000]
#
# --2026-05-16 17:42:19--  https://physionet.org/files/ptb-xl/1.0.3/records100/21000/21609_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 607 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21609_lr.hea’
#
# records100/21000/21 100%[===================>]     607  --.-KB/s    in 0s
#
# 2026-05-16 17:42:19 (79.9 MB/s) - ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21609_lr.hea’ saved [607/607]
#
# --2026-05-16 17:42:19--  https://physionet.org/files/ptb-xl/1.0.3/records100/21000/21610_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21610_lr.dat’
#
# records100/21000/21 100%[===================>]  23.44K  --.-KB/s    in 0.04s
#
# 2026-05-16 17:42:20 (622 KB/s) - ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21610_lr.dat’ saved [24000/24000]
#
# --2026-05-16 17:42:20--  https://physionet.org/files/ptb-xl/1.0.3/records100/21000/21610_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 594 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21610_lr.hea’
#
# records100/21000/21 100%[===================>]     594  --.-KB/s    in 0s
#
# 2026-05-16 17:42:20 (67.5 MB/s) - ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21610_lr.hea’ saved [594/594]
#
# --2026-05-16 17:42:20--  https://physionet.org/files/ptb-xl/1.0.3/records100/21000/21611_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21611_lr.dat’
#
# records100/21000/21 100%[===================>]  23.44K  --.-KB/s    in 0.04s
#
# 2026-05-16 17:42:20 (620 KB/s) - ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21611_lr.dat’ saved [24000/24000]
#
# --2026-05-16 17:42:20--  https://physionet.org/files/ptb-xl/1.0.3/records100/21000/21611_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 601 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21611_lr.hea’
#
# records100/21000/21 100%[===================>]     601  --.-KB/s    in 0s
#
# 2026-05-16 17:42:20 (82.5 MB/s) - ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21611_lr.hea’ saved [601/601]
#
# --2026-05-16 17:42:20--  https://physionet.org/files/ptb-xl/1.0.3/records100/21000/21612_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21612_lr.dat’
#
# records100/21000/21 100%[===================>]  23.44K  --.-KB/s    in 0.04s
#
# 2026-05-16 17:42:21 (590 KB/s) - ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21612_lr.dat’ saved [24000/24000]
#
# --2026-05-16 17:42:21--  https://physionet.org/files/ptb-xl/1.0.3/records100/21000/21612_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 611 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21612_lr.hea’
#
# records100/21000/21 100%[===================>]     611  --.-KB/s    in 0s
#
# 2026-05-16 17:42:21 (84.4 MB/s) - ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21612_lr.hea’ saved [611/611]
#
# --2026-05-16 17:42:21--  https://physionet.org/files/ptb-xl/1.0.3/records100/21000/21613_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21613_lr.dat’
#
# records100/21000/21 100%[===================>]  23.44K  --.-KB/s    in 0.03s
#
# 2026-05-16 17:42:21 (686 KB/s) - ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21613_lr.dat’ saved [24000/24000]
#
# --2026-05-16 17:42:21--  https://physionet.org/files/ptb-xl/1.0.3/records100/21000/21613_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 603 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21613_lr.hea’
#
# records100/21000/21 100%[===================>]     603  --.-KB/s    in 0s
#
# 2026-05-16 17:42:21 (80.5 MB/s) - ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21613_lr.hea’ saved [603/603]
#
# --2026-05-16 17:42:21--  https://physionet.org/files/ptb-xl/1.0.3/records100/21000/21614_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21614_lr.dat’
#
# records100/21000/21 100%[===================>]  23.44K  --.-KB/s    in 0.1s
#
# 2026-05-16 17:42:22 (245 KB/s) - ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21614_lr.dat’ saved [24000/24000]
#
# --2026-05-16 17:42:22--  https://physionet.org/files/ptb-xl/1.0.3/records100/21000/21614_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 602 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21614_lr.hea’
#
# records100/21000/21 100%[===================>]     602  --.-KB/s    in 0s
#
# 2026-05-16 17:42:22 (76.5 MB/s) - ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21614_lr.hea’ saved [602/602]
#
# --2026-05-16 17:42:22--  https://physionet.org/files/ptb-xl/1.0.3/records100/21000/21615_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21615_lr.dat’
#
# records100/21000/21 100%[===================>]  23.44K  --.-KB/s    in 0.04s
#
# 2026-05-16 17:42:22 (608 KB/s) - ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21615_lr.dat’ saved [24000/24000]
#
# --2026-05-16 17:42:22--  https://physionet.org/files/ptb-xl/1.0.3/records100/21000/21615_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 600 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21615_lr.hea’
#
# records100/21000/21 100%[===================>]     600  --.-KB/s    in 0s
#
# 2026-05-16 17:42:22 (81.7 MB/s) - ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21615_lr.hea’ saved [600/600]
#
# --2026-05-16 17:42:22--  https://physionet.org/files/ptb-xl/1.0.3/records100/21000/21616_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21616_lr.dat’
#
# records100/21000/21 100%[===================>]  23.44K  --.-KB/s    in 0.04s
#
# 2026-05-16 17:42:22 (632 KB/s) - ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21616_lr.dat’ saved [24000/24000]
#
# --2026-05-16 17:42:22--  https://physionet.org/files/ptb-xl/1.0.3/records100/21000/21616_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 607 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21616_lr.hea’
#
# records100/21000/21 100%[===================>]     607  --.-KB/s    in 0s
#
# 2026-05-16 17:42:23 (70.0 MB/s) - ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21616_lr.hea’ saved [607/607]
#
# --2026-05-16 17:42:23--  https://physionet.org/files/ptb-xl/1.0.3/records100/21000/21617_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21617_lr.dat’
#
# records100/21000/21 100%[===================>]  23.44K  --.-KB/s    in 0.04s
#
# 2026-05-16 17:42:23 (636 KB/s) - ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21617_lr.dat’ saved [24000/24000]
#
# --2026-05-16 17:42:23--  https://physionet.org/files/ptb-xl/1.0.3/records100/21000/21617_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 593 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21617_lr.hea’
#
# records100/21000/21 100%[===================>]     593  --.-KB/s    in 0s
#
# 2026-05-16 17:42:23 (79.0 MB/s) - ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21617_lr.hea’ saved [593/593]
#
# --2026-05-16 17:42:23--  https://physionet.org/files/ptb-xl/1.0.3/records100/21000/21618_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21618_lr.dat’
#
# records100/21000/21 100%[===================>]  23.44K  --.-KB/s    in 0.1s
#
# 2026-05-16 17:42:23 (238 KB/s) - ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21618_lr.dat’ saved [24000/24000]
#
# --2026-05-16 17:42:23--  https://physionet.org/files/ptb-xl/1.0.3/records100/21000/21618_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 602 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21618_lr.hea’
#
# records100/21000/21 100%[===================>]     602  --.-KB/s    in 0s
#
# 2026-05-16 17:42:23 (69.4 MB/s) - ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21618_lr.hea’ saved [602/602]
#
# --2026-05-16 17:42:23--  https://physionet.org/files/ptb-xl/1.0.3/records100/21000/21619_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21619_lr.dat’
#
# records100/21000/21 100%[===================>]  23.44K  --.-KB/s    in 0.04s
#
# 2026-05-16 17:42:24 (636 KB/s) - ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21619_lr.dat’ saved [24000/24000]
#
# --2026-05-16 17:42:24--  https://physionet.org/files/ptb-xl/1.0.3/records100/21000/21619_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 605 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21619_lr.hea’
#
# records100/21000/21 100%[===================>]     605  --.-KB/s    in 0s
#
# 2026-05-16 17:42:24 (13.4 MB/s) - ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21619_lr.hea’ saved [605/605]
#
# --2026-05-16 17:42:24--  https://physionet.org/files/ptb-xl/1.0.3/records100/21000/21620_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21620_lr.dat’
#
# records100/21000/21 100%[===================>]  23.44K  --.-KB/s    in 0.04s
#
# 2026-05-16 17:42:24 (648 KB/s) - ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21620_lr.dat’ saved [24000/24000]
#
# --2026-05-16 17:42:24--  https://physionet.org/files/ptb-xl/1.0.3/records100/21000/21620_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 604 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21620_lr.hea’
#
# records100/21000/21 100%[===================>]     604  --.-KB/s    in 0s
#
# 2026-05-16 17:42:24 (60.5 MB/s) - ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21620_lr.hea’ saved [604/604]
#
# --2026-05-16 17:42:24--  https://physionet.org/files/ptb-xl/1.0.3/records100/21000/21621_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21621_lr.dat’
#
# records100/21000/21 100%[===================>]  23.44K  --.-KB/s    in 0.003s
#
# 2026-05-16 17:42:25 (8.44 MB/s) - ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21621_lr.dat’ saved [24000/24000]
#
# --2026-05-16 17:42:25--  https://physionet.org/files/ptb-xl/1.0.3/records100/21000/21621_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 613 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21621_lr.hea’
#
# records100/21000/21 100%[===================>]     613  --.-KB/s    in 0s
#
# 2026-05-16 17:42:25 (65.7 MB/s) - ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21621_lr.hea’ saved [613/613]
#
# --2026-05-16 17:42:25--  https://physionet.org/files/ptb-xl/1.0.3/records100/21000/21622_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21622_lr.dat’
#
# records100/21000/21 100%[===================>]  23.44K  --.-KB/s    in 0.07s
#
# 2026-05-16 17:42:25 (330 KB/s) - ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21622_lr.dat’ saved [24000/24000]
#
# --2026-05-16 17:42:25--  https://physionet.org/files/ptb-xl/1.0.3/records100/21000/21622_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 602 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21622_lr.hea’
#
# records100/21000/21 100%[===================>]     602  --.-KB/s    in 0s
#
# 2026-05-16 17:42:26 (71.6 MB/s) - ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21622_lr.hea’ saved [602/602]
#
# --2026-05-16 17:42:26--  https://physionet.org/files/ptb-xl/1.0.3/records100/21000/21623_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21623_lr.dat’
#
# records100/21000/21 100%[===================>]  23.44K  82.1KB/s    in 0.3s
#
# 2026-05-16 17:42:26 (82.1 KB/s) - ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21623_lr.dat’ saved [24000/24000]
#
# --2026-05-16 17:42:26--  https://physionet.org/files/ptb-xl/1.0.3/records100/21000/21623_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 601 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21623_lr.hea’
#
# records100/21000/21 100%[===================>]     601  --.-KB/s    in 0s
#
# 2026-05-16 17:42:27 (74.0 MB/s) - ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21623_lr.hea’ saved [601/601]
#
# --2026-05-16 17:42:27--  https://physionet.org/files/ptb-xl/1.0.3/records100/21000/21624_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21624_lr.dat’
#
# records100/21000/21 100%[===================>]  23.44K  --.-KB/s    in 0.03s
#
# 2026-05-16 17:42:27 (750 KB/s) - ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21624_lr.dat’ saved [24000/24000]
#
# --2026-05-16 17:42:27--  https://physionet.org/files/ptb-xl/1.0.3/records100/21000/21624_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 606 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21624_lr.hea’
#
# records100/21000/21 100%[===================>]     606  --.-KB/s    in 0s
#
# 2026-05-16 17:42:28 (72.0 MB/s) - ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21624_lr.hea’ saved [606/606]
#
# --2026-05-16 17:42:28--  https://physionet.org/files/ptb-xl/1.0.3/records100/21000/21625_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21625_lr.dat’
#
# records100/21000/21 100%[===================>]  23.44K  --.-KB/s    in 0.08s
#
# 2026-05-16 17:42:28 (300 KB/s) - ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21625_lr.dat’ saved [24000/24000]
#
# --2026-05-16 17:42:28--  https://physionet.org/files/ptb-xl/1.0.3/records100/21000/21625_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 600 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21625_lr.hea’
#
# records100/21000/21 100%[===================>]     600  --.-KB/s    in 0s
#
# 2026-05-16 17:42:28 (74.1 MB/s) - ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21625_lr.hea’ saved [600/600]
#
# --2026-05-16 17:42:28--  https://physionet.org/files/ptb-xl/1.0.3/records100/21000/21626_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21626_lr.dat’
#
# records100/21000/21 100%[===================>]  23.44K  --.-KB/s    in 0.03s
#
# 2026-05-16 17:42:28 (743 KB/s) - ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21626_lr.dat’ saved [24000/24000]
#
# --2026-05-16 17:42:28--  https://physionet.org/files/ptb-xl/1.0.3/records100/21000/21626_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 598 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21626_lr.hea’
#
# records100/21000/21 100%[===================>]     598  --.-KB/s    in 0s
#
# 2026-05-16 17:42:28 (64.0 MB/s) - ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21626_lr.hea’ saved [598/598]
#
# --2026-05-16 17:42:28--  https://physionet.org/files/ptb-xl/1.0.3/records100/21000/21627_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21627_lr.dat’
#
# records100/21000/21 100%[===================>]  23.44K  --.-KB/s    in 0.1s
#
# 2026-05-16 17:42:29 (217 KB/s) - ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21627_lr.dat’ saved [24000/24000]
#
# --2026-05-16 17:42:29--  https://physionet.org/files/ptb-xl/1.0.3/records100/21000/21627_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 601 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21627_lr.hea’
#
# records100/21000/21 100%[===================>]     601  --.-KB/s    in 0s
#
# 2026-05-16 17:42:29 (82.3 MB/s) - ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21627_lr.hea’ saved [601/601]
#
# --2026-05-16 17:42:29--  https://physionet.org/files/ptb-xl/1.0.3/records100/21000/21628_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21628_lr.dat’
#
# records100/21000/21 100%[===================>]  23.44K  --.-KB/s    in 0.03s
#
# 2026-05-16 17:42:29 (695 KB/s) - ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21628_lr.dat’ saved [24000/24000]
#
# --2026-05-16 17:42:29--  https://physionet.org/files/ptb-xl/1.0.3/records100/21000/21628_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 598 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21628_lr.hea’
#
# records100/21000/21 100%[===================>]     598  --.-KB/s    in 0s
#
# 2026-05-16 17:42:29 (81.8 MB/s) - ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21628_lr.hea’ saved [598/598]
#
# --2026-05-16 17:42:29--  https://physionet.org/files/ptb-xl/1.0.3/records100/21000/21629_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21629_lr.dat’
#
# records100/21000/21 100%[===================>]  23.44K  --.-KB/s    in 0.03s
#
# 2026-05-16 17:42:30 (768 KB/s) - ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21629_lr.dat’ saved [24000/24000]
#
# --2026-05-16 17:42:30--  https://physionet.org/files/ptb-xl/1.0.3/records100/21000/21629_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 592 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21629_lr.hea’
#
# records100/21000/21 100%[===================>]     592  --.-KB/s    in 0s
#
# 2026-05-16 17:42:30 (67.5 MB/s) - ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21629_lr.hea’ saved [592/592]
#
# --2026-05-16 17:42:30--  https://physionet.org/files/ptb-xl/1.0.3/records100/21000/21630_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21630_lr.dat’
#
# records100/21000/21 100%[===================>]  23.44K  --.-KB/s    in 0.03s
#
# 2026-05-16 17:42:30 (810 KB/s) - ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21630_lr.dat’ saved [24000/24000]
#
# --2026-05-16 17:42:30--  https://physionet.org/files/ptb-xl/1.0.3/records100/21000/21630_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 606 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21630_lr.hea’
#
# records100/21000/21 100%[===================>]     606  --.-KB/s    in 0s
#
# 2026-05-16 17:42:30 (75.9 MB/s) - ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21630_lr.hea’ saved [606/606]
#
# --2026-05-16 17:42:30--  https://physionet.org/files/ptb-xl/1.0.3/records100/21000/21631_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21631_lr.dat’
#
# records100/21000/21 100%[===================>]  23.44K  --.-KB/s    in 0.04s
#
# 2026-05-16 17:42:30 (639 KB/s) - ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21631_lr.dat’ saved [24000/24000]
#
# --2026-05-16 17:42:30--  https://physionet.org/files/ptb-xl/1.0.3/records100/21000/21631_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 597 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21631_lr.hea’
#
# records100/21000/21 100%[===================>]     597  --.-KB/s    in 0s
#
# 2026-05-16 17:42:31 (77.7 MB/s) - ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21631_lr.hea’ saved [597/597]
#
# --2026-05-16 17:42:31--  https://physionet.org/files/ptb-xl/1.0.3/records100/21000/21632_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21632_lr.dat’
#
# records100/21000/21 100%[===================>]  23.44K  --.-KB/s    in 0.09s
#
# 2026-05-16 17:42:31 (256 KB/s) - ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21632_lr.dat’ saved [24000/24000]
#
# --2026-05-16 17:42:31--  https://physionet.org/files/ptb-xl/1.0.3/records100/21000/21632_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 611 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21632_lr.hea’
#
# records100/21000/21 100%[===================>]     611  --.-KB/s    in 0s
#
# 2026-05-16 17:42:31 (87.8 MB/s) - ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21632_lr.hea’ saved [611/611]
#
# --2026-05-16 17:42:31--  https://physionet.org/files/ptb-xl/1.0.3/records100/21000/21633_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21633_lr.dat’
#
# records100/21000/21 100%[===================>]  23.44K  --.-KB/s    in 0.04s
#
# 2026-05-16 17:42:31 (567 KB/s) - ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21633_lr.dat’ saved [24000/24000]
#
# ...
# Saving to: ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21823_lr.dat’
#
# records100/21000/21 100%[===================>]  23.44K  --.-KB/s    in 0.02s
#
# 2026-05-16 17:43:52 (1.52 MB/s) - ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21823_lr.dat’ saved [24000/24000]
#
# --2026-05-16 17:43:52--  https://physionet.org/files/ptb-xl/1.0.3/records100/21000/21823_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 605 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21823_lr.hea’
#
# records100/21000/21 100%[===================>]     605  --.-KB/s    in 0s
#
# 2026-05-16 17:43:52 (58.2 MB/s) - ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21823_lr.hea’ saved [605/605]
#
# --2026-05-16 17:43:52--  https://physionet.org/files/ptb-xl/1.0.3/records100/21000/21824_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21824_lr.dat’
#
# records100/21000/21 100%[===================>]  23.44K  --.-KB/s    in 0.07s
#
# 2026-05-16 17:43:53 (349 KB/s) - ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21824_lr.dat’ saved [24000/24000]
#
# --2026-05-16 17:43:53--  https://physionet.org/files/ptb-xl/1.0.3/records100/21000/21824_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 608 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21824_lr.hea’
#
# records100/21000/21 100%[===================>]     608  --.-KB/s    in 0s
#
# 2026-05-16 17:43:53 (72.3 MB/s) - ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21824_lr.hea’ saved [608/608]
#
# --2026-05-16 17:43:53--  https://physionet.org/files/ptb-xl/1.0.3/records100/21000/21825_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21825_lr.dat’
#
# records100/21000/21 100%[===================>]  23.44K  --.-KB/s    in 0.04s
#
# 2026-05-16 17:43:53 (584 KB/s) - ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21825_lr.dat’ saved [24000/24000]
#
# --2026-05-16 17:43:53--  https://physionet.org/files/ptb-xl/1.0.3/records100/21000/21825_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 600 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21825_lr.hea’
#
# records100/21000/21 100%[===================>]     600  --.-KB/s    in 0s
#
# 2026-05-16 17:43:53 (71.1 MB/s) - ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21825_lr.hea’ saved [600/600]
#
# --2026-05-16 17:43:53--  https://physionet.org/files/ptb-xl/1.0.3/records100/21000/21826_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21826_lr.dat’
#
# records100/21000/21 100%[===================>]  23.44K  --.-KB/s    in 0.06s
#
# 2026-05-16 17:43:54 (362 KB/s) - ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21826_lr.dat’ saved [24000/24000]
#
# --2026-05-16 17:43:54--  https://physionet.org/files/ptb-xl/1.0.3/records100/21000/21826_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 592 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21826_lr.hea’
#
# records100/21000/21 100%[===================>]     592  --.-KB/s    in 0s
#
# 2026-05-16 17:43:54 (76.2 MB/s) - ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21826_lr.hea’ saved [592/592]
#
# --2026-05-16 17:43:54--  https://physionet.org/files/ptb-xl/1.0.3/records100/21000/21827_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21827_lr.dat’
#
# records100/21000/21 100%[===================>]  23.44K  --.-KB/s    in 0.06s
#
# 2026-05-16 17:43:54 (406 KB/s) - ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21827_lr.dat’ saved [24000/24000]
#
# --2026-05-16 17:43:54--  https://physionet.org/files/ptb-xl/1.0.3/records100/21000/21827_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 600 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21827_lr.hea’
#
# records100/21000/21 100%[===================>]     600  --.-KB/s    in 0s
#
# 2026-05-16 17:43:54 (74.7 MB/s) - ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21827_lr.hea’ saved [600/600]
#
# --2026-05-16 17:43:54--  https://physionet.org/files/ptb-xl/1.0.3/records100/21000/21828_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21828_lr.dat’
#
# records100/21000/21 100%[===================>]  23.44K  --.-KB/s    in 0.004s
#
# 2026-05-16 17:43:55 (6.49 MB/s) - ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21828_lr.dat’ saved [24000/24000]
#
# --2026-05-16 17:43:55--  https://physionet.org/files/ptb-xl/1.0.3/records100/21000/21828_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 592 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21828_lr.hea’
#
# records100/21000/21 100%[===================>]     592  --.-KB/s    in 0s
#
# 2026-05-16 17:43:55 (77.1 MB/s) - ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21828_lr.hea’ saved [592/592]
#
# --2026-05-16 17:43:55--  https://physionet.org/files/ptb-xl/1.0.3/records100/21000/21829_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21829_lr.dat’
#
# records100/21000/21 100%[===================>]  23.44K   127KB/s    in 0.2s
#
# 2026-05-16 17:43:55 (127 KB/s) - ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21829_lr.dat’ saved [24000/24000]
#
# --2026-05-16 17:43:55--  https://physionet.org/files/ptb-xl/1.0.3/records100/21000/21829_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 605 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21829_lr.hea’
#
# records100/21000/21 100%[===================>]     605  --.-KB/s    in 0s
#
# 2026-05-16 17:43:56 (82.2 MB/s) - ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21829_lr.hea’ saved [605/605]
#
# --2026-05-16 17:43:56--  https://physionet.org/files/ptb-xl/1.0.3/records100/21000/21830_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21830_lr.dat’
#
# records100/21000/21 100%[===================>]  23.44K  --.-KB/s    in 0.07s
#
# 2026-05-16 17:43:56 (341 KB/s) - ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21830_lr.dat’ saved [24000/24000]
#
# --2026-05-16 17:43:56--  https://physionet.org/files/ptb-xl/1.0.3/records100/21000/21830_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 614 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21830_lr.hea’
#
# records100/21000/21 100%[===================>]     614  --.-KB/s    in 0s
#
# 2026-05-16 17:43:56 (76.2 MB/s) - ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21830_lr.hea’ saved [614/614]
#
# --2026-05-16 17:43:56--  https://physionet.org/files/ptb-xl/1.0.3/records100/21000/21831_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21831_lr.dat’
#
# records100/21000/21 100%[===================>]  23.44K  --.-KB/s    in 0.04s
#
# 2026-05-16 17:43:57 (593 KB/s) - ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21831_lr.dat’ saved [24000/24000]
#
# --2026-05-16 17:43:57--  https://physionet.org/files/ptb-xl/1.0.3/records100/21000/21831_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 606 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21831_lr.hea’
#
# records100/21000/21 100%[===================>]     606  --.-KB/s    in 0s
#
# 2026-05-16 17:43:57 (84.7 MB/s) - ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21831_lr.hea’ saved [606/606]
#
# --2026-05-16 17:43:57--  https://physionet.org/files/ptb-xl/1.0.3/records100/21000/21832_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21832_lr.dat’
#
# records100/21000/21 100%[===================>]  23.44K   140KB/s    in 0.2s
#
# 2026-05-16 17:43:57 (140 KB/s) - ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21832_lr.dat’ saved [24000/24000]
#
# --2026-05-16 17:43:57--  https://physionet.org/files/ptb-xl/1.0.3/records100/21000/21832_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 599 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21832_lr.hea’
#
# records100/21000/21 100%[===================>]     599  --.-KB/s    in 0s
#
# 2026-05-16 17:43:57 (80.3 MB/s) - ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21832_lr.hea’ saved [599/599]
#
# --2026-05-16 17:43:57--  https://physionet.org/files/ptb-xl/1.0.3/records100/21000/21833_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21833_lr.dat’
#
# records100/21000/21 100%[===================>]  23.44K  --.-KB/s    in 0.07s
#
# 2026-05-16 17:43:58 (350 KB/s) - ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21833_lr.dat’ saved [24000/24000]
#
# --2026-05-16 17:43:58--  https://physionet.org/files/ptb-xl/1.0.3/records100/21000/21833_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 603 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21833_lr.hea’
#
# records100/21000/21 100%[===================>]     603  --.-KB/s    in 0s
#
# 2026-05-16 17:43:58 (81.2 MB/s) - ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21833_lr.hea’ saved [603/603]
#
# --2026-05-16 17:43:58--  https://physionet.org/files/ptb-xl/1.0.3/records100/21000/21834_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21834_lr.dat’
#
# records100/21000/21 100%[===================>]  23.44K  --.-KB/s    in 0.1s
#
# 2026-05-16 17:43:58 (208 KB/s) - ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21834_lr.dat’ saved [24000/24000]
#
# --2026-05-16 17:43:58--  https://physionet.org/files/ptb-xl/1.0.3/records100/21000/21834_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 601 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21834_lr.hea’
#
# records100/21000/21 100%[===================>]     601  --.-KB/s    in 0s
#
# 2026-05-16 17:43:58 (91.9 MB/s) - ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21834_lr.hea’ saved [601/601]
#
# --2026-05-16 17:43:58--  https://physionet.org/files/ptb-xl/1.0.3/records100/21000/21835_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21835_lr.dat’
#
# records100/21000/21 100%[===================>]  23.44K  --.-KB/s    in 0.07s
#
# 2026-05-16 17:43:59 (347 KB/s) - ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21835_lr.dat’ saved [24000/24000]
#
# --2026-05-16 17:43:59--  https://physionet.org/files/ptb-xl/1.0.3/records100/21000/21835_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 594 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21835_lr.hea’
#
# records100/21000/21 100%[===================>]     594  --.-KB/s    in 0s
#
# 2026-05-16 17:43:59 (76.7 MB/s) - ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21835_lr.hea’ saved [594/594]
#
# --2026-05-16 17:43:59--  https://physionet.org/files/ptb-xl/1.0.3/records100/21000/21836_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21836_lr.dat’
#
# records100/21000/21 100%[===================>]  23.44K  --.-KB/s    in 0.004s
#
# 2026-05-16 17:43:59 (5.18 MB/s) - ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21836_lr.dat’ saved [24000/24000]
#
# --2026-05-16 17:43:59--  https://physionet.org/files/ptb-xl/1.0.3/records100/21000/21836_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 603 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21836_lr.hea’
#
# records100/21000/21 100%[===================>]     603  --.-KB/s    in 0s
#
# 2026-05-16 17:43:59 (68.3 MB/s) - ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21836_lr.hea’ saved [603/603]
#
# --2026-05-16 17:43:59--  https://physionet.org/files/ptb-xl/1.0.3/records100/21000/21837_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21837_lr.dat’
#
# records100/21000/21 100%[===================>]  23.44K  --.-KB/s    in 0.07s
#
# 2026-05-16 17:44:00 (352 KB/s) - ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21837_lr.dat’ saved [24000/24000]
#
# --2026-05-16 17:44:00--  https://physionet.org/files/ptb-xl/1.0.3/records100/21000/21837_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 607 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21837_lr.hea’
#
# records100/21000/21 100%[===================>]     607  --.-KB/s    in 0s
#
# 2026-05-16 17:44:00 (77.3 MB/s) - ‘/content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/21000/21837_lr.hea’ saved [607/607]
#
# FINISHED --2026-05-16 17:44:00--
# Total wall clock time: 2h 26m 9s
# Downloaded: 38368 files, 455M in 16m 14s (478 KB/s)
# Metadata exists: True /content/drive/MyDrive/ptbxl_mi_project/ptbxl/ptbxl_database.csv
# SCP exists: True /content/drive/MyDrive/ptbxl_mi_project/ptbxl/scp_statements.csv
# Download/check cell finished.

# %% [markdown]
# ## 5. Load metadata and create binary MI labels

# %%
df = pd.read_csv(metadata_path, index_col="ecg_id")
scp_statements = pd.read_csv(scp_path, index_col=0)

print("Metadata shape:", df.shape)
print("SCP statements shape:", scp_statements.shape)
print(df[["filename_lr", "strat_fold", "scp_codes"]].head())
print(scp_statements.head())
# Out:
# Metadata shape: (21799, 27)
# SCP statements shape: (71, 12)
#                       filename_lr  strat_fold  \
# ecg_id
# 1       records100/00000/00001_lr           3
# 2       records100/00000/00002_lr           2
# 3       records100/00000/00003_lr           5
# 4       records100/00000/00004_lr           3
# 5       records100/00000/00005_lr           4
#
#                                        scp_codes
# ecg_id
# 1       {'NORM': 100.0, 'LVOLT': 0.0, 'SR': 0.0}
# 2                   {'NORM': 80.0, 'SBRAD': 0.0}
# 3                     {'NORM': 100.0, 'SR': 0.0}
# 4                     {'NORM': 100.0, 'SR': 0.0}
# 5                     {'NORM': 100.0, 'SR': 0.0}
#                           description  diagnostic  form  rhythm  \
# NDT    non-diagnostic T abnormalities         1.0   1.0     NaN
# NST_          non-specific ST changes         1.0   1.0     NaN
# DIG                  digitalis-effect         1.0   1.0     NaN
# LNGQT                long QT-interval         1.0   1.0     NaN
# NORM                       normal ECG         1.0   NaN     NaN
#
#       diagnostic_class diagnostic_subclass  \
# NDT               STTC                STTC
# NST_              STTC                NST_
# DIG               STTC                STTC
# LNGQT             STTC                STTC
# NORM              NORM                NORM
#
#                                       Statement Category  \
# NDT                    other ST-T descriptive statements
# NST_   Basic roots for coding ST-T changes and abnorm...
# DIG                    other ST-T descriptive statements
# LNGQT                  other ST-T descriptive statements
# NORM                                     Normal/abnormal
#
#         SCP-ECG Statement Description  AHA code            aECG REFID  \
# NDT    non-diagnostic T abnormalities       NaN                   NaN
# NST_          non-specific ST changes     145.0  MDC_ECG_RHY_STHILOST
# DIG         suggests digitalis-effect     205.0                   NaN
# LNGQT                long QT-interval     148.0                   NaN
# NORM                       normal ECG       1.0                   NaN
#
#       CDISC Code DICOM Code
# NDT          NaN        NaN
# NST_         NaN        NaN
# DIG          NaN        NaN
# LNGQT        NaN        NaN
# NORM         NaN    F-000B7

# %%
# PTB-XL stores SCP codes as strings like "{'NORM': 100.0, 'IMI': 15.0}".
df["scp_codes_dict"] = df["scp_codes"].apply(ast.literal_eval)

# Keep diagnostic SCP codes only.
diagnostic_scp = scp_statements[scp_statements["diagnostic"] == 1.0]

def aggregate_diagnostic_classes(scp_code_dict):
    diagnostic_classes = []
    for code in scp_code_dict.keys():
        if code in diagnostic_scp.index:
            diagnostic_classes.append(diagnostic_scp.loc[code, "diagnostic_class"])
    return list(set(diagnostic_classes))

df["diagnostic_superclass"] = df["scp_codes_dict"].apply(aggregate_diagnostic_classes)
df["MI_label"] = df["diagnostic_superclass"].apply(lambda classes: int("MI" in classes))

print(df[["scp_codes", "diagnostic_superclass", "MI_label", "strat_fold"]].head())
print("\nClass distribution:")
print(df["MI_label"].value_counts())
print("\nClass distribution normalized:")
print(df["MI_label"].value_counts(normalize=True))
# Out:
#                                        scp_codes diagnostic_superclass  \
# ecg_id
# 1       {'NORM': 100.0, 'LVOLT': 0.0, 'SR': 0.0}                [NORM]
# 2                   {'NORM': 80.0, 'SBRAD': 0.0}                [NORM]
# 3                     {'NORM': 100.0, 'SR': 0.0}                [NORM]
# 4                     {'NORM': 100.0, 'SR': 0.0}                [NORM]
# 5                     {'NORM': 100.0, 'SR': 0.0}                [NORM]
#
#         MI_label  strat_fold
# ecg_id
# 1              0           3
# 2              0           2
# 3              0           5
# 4              0           3
# 5              0           4
#
# Class distribution:
# MI_label
# 0    16330
# 1     5469
# Name: count, dtype: int64
#
# Class distribution normalized:
# MI_label
# 0    0.749117
# 1    0.250883
# Name: proportion, dtype: float64

# %%
from pathlib import Path
import subprocess
from tqdm import tqdm

BASE_URL = "https://physionet.org/files/ptb-xl/1.0.3"

def find_missing_record_files(metadata_df, data_dir, max_report=20):
    missing = []

    for fname in tqdm(metadata_df["filename_lr"].values, desc="Checking ECG files"):
        record_base = data_dir / fname

        hea_path = Path(str(record_base) + ".hea")
        dat_path = Path(str(record_base) + ".dat")

        if not hea_path.exists():
            missing.append(hea_path)

        if not dat_path.exists():
            missing.append(dat_path)

    print(f"Total missing files: {len(missing)}")

    if len(missing) > 0:
        print("First missing files:")
        for m in missing[:max_report]:
            print(m)

    return missing


def download_missing_files(missing_files, data_dir):
    """
    Downloads only missing .hea/.dat files from PhysioNet.
    """

    for local_path in tqdm(missing_files, desc="Downloading missing files"):
        local_path = Path(local_path)

        # Make parent folder if needed
        local_path.parent.mkdir(parents=True, exist_ok=True)

        # Convert local path to relative path under DATA_DIR
        rel_path = local_path.relative_to(data_dir)

        # Build PhysioNet URL
        url = f"{BASE_URL}/{rel_path.as_posix()}"

        cmd = [
            "wget",
            "-c",
            "--tries=30",
            "--waitretry=10",
            "--read-timeout=60",
            "--timeout=30",
            "-O",
            str(local_path),
            url,
        ]

        result = subprocess.run(
            cmd,
            stdout=subprocess.DEVNULL,
            stderr=subprocess.DEVNULL,
        )

        if result.returncode != 0:
            print(f"Failed to download: {url}")


missing = find_missing_record_files(df, DATA_DIR)

if len(missing) > 0:
    print("Downloading only missing files...")
    download_missing_files(missing, DATA_DIR)

    # Recheck after download
    missing_after = find_missing_record_files(df, DATA_DIR)

    if len(missing_after) > 0:
        print("Some files are still missing. Run this same cell again.")
    else:
        print("All required records100 files are now available.")
else:
    print("All required records100 files are available.")
# Out:
# Checking ECG files: 100%|██████████| 21799/21799 [00:16<00:00, 1348.54it/s]
# Total missing files: 280
# First missing files:
# /content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/02000/02628_lr.hea
# /content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/02000/02837_lr.hea
# /content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/02000/02838_lr.dat
# /content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/02000/02906_lr.hea
# /content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/02000/02908_lr.hea
# /content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/02000/02920_lr.hea
# /content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/03000/03100_lr.hea
# /content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/03000/03101_lr.dat
# /content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/04000/04000_lr.dat
# /content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/04000/04001_lr.hea
# /content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/04000/04001_lr.dat
# /content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/04000/04368_lr.dat
# /content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/05000/05139_lr.hea
# /content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/05000/05139_lr.dat
# /content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/05000/05140_lr.hea
# /content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/05000/05140_lr.dat
# /content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/05000/05173_lr.dat
# /content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/06000/06554_lr.hea
# /content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/07000/07800_lr.hea
# /content/drive/MyDrive/ptbxl_mi_project/ptbxl/records100/07000/07898_lr.dat
# Downloading only missing files...
# Downloading missing files: 100%|██████████| 280/280 [02:00<00:00,  2.33it/s]
# Checking ECG files: 100%|██████████| 21799/21799 [00:14<00:00, 1529.33it/s]
# Total missing files: 0
# All required records100 files are now available.

# %% [markdown]
# ## 6. Verify that ECG files exist

# %% [markdown]
# ## 7. Official PTB-XL fold split

# %%
# Official split used in the paper:
# folds 1-8: training
# fold 9: validation
# fold 10: final test

train_df = df[df["strat_fold"].isin([1, 2, 3, 4, 5, 6, 7, 8])].copy()
val_df = df[df["strat_fold"] == 9].copy()
test_df = df[df["strat_fold"] == 10].copy()

print("Train:", train_df.shape, train_df["MI_label"].value_counts().to_dict())
print("Val:", val_df.shape, val_df["MI_label"].value_counts().to_dict())
print("Test:", test_df.shape, test_df["MI_label"].value_counts().to_dict())

assert set(train_df["strat_fold"].unique()).issubset(set(range(1, 9)))
assert set(val_df["strat_fold"].unique()) == {9}
assert set(test_df["strat_fold"].unique()) == {10}
# Out:
# Train: (17418, 30) {0: 13039, 1: 4379}
# Val: (2183, 30) {0: 1643, 1: 540}
# Test: (2198, 30) {0: 1648, 1: 550}

# %%
from pathlib import Path
import shutil
import os

DRIVE_DATA_DIR = Path("/content/drive/MyDrive/ptbxl_mi_project/ptbxl")
LOCAL_DATA_DIR = Path("/content/ptbxl")

if not LOCAL_DATA_DIR.exists():
    print("Copying PTB-XL from Google Drive to Colab local disk...")
    # !cp -r "{DRIVE_DATA_DIR}" "{LOCAL_DATA_DIR}"
else:
    print("Local PTB-XL already exists.")

DATA_DIR = LOCAL_DATA_DIR

print("Using DATA_DIR:", DATA_DIR)
# Out:
# Copying PTB-XL from Google Drive to Colab local disk...
# Using DATA_DIR: /content/ptbxl

# %%
X_train, y_train = load_raw_data(train_df, DATA_DIR)
X_val, y_val = load_raw_data(val_df, DATA_DIR)
X_test, y_test = load_raw_data(test_df, DATA_DIR)
# Out:
# Loading ECG records: 100%|██████████| 17418/17418 [04:00<00:00, 72.39it/s]
# Loading ECG records: 100%|██████████| 2183/2183 [00:29<00:00, 75.14it/s]
# Loading ECG records: 100%|██████████| 2198/2198 [00:34<00:00, 64.34it/s]

# %% [markdown]
# ## 8. Load 100 Hz ECG signals

# %%
def load_raw_data(metadata_subset, data_dir):
    '''
    Loads PTB-XL 100 Hz ECG records.

    wfdb returns signal shape [1000, 12].
    For PyTorch Conv1D, we transpose to [12, 1000].
    '''
    signals = []
    labels = []

    for _, row in tqdm(metadata_subset.iterrows(), total=len(metadata_subset), desc="Loading ECG records"):
        record_path = data_dir / row["filename_lr"]

        try:
            signal, meta = wfdb.rdsamp(str(record_path))
        except Exception as e:
            raise RuntimeError(f"Failed to read {record_path}. Error: {e}")

        # Expected raw shape: [time, leads] = [1000, 12]
        if signal.shape != (1000, 12):
            raise ValueError(f"Unexpected signal shape {signal.shape} for {record_path}")

        # Convert to [leads, time] = [12, 1000]
        signal = signal.T.astype(np.float32)

        signals.append(signal)
        labels.append(row["MI_label"])

    X = np.stack(signals).astype(np.float32)
    y = np.array(labels).astype(np.float32)

    return X, y

X_train, y_train = load_raw_data(train_df, DATA_DIR)
X_val, y_val = load_raw_data(val_df, DATA_DIR)
X_test, y_test = load_raw_data(test_df, DATA_DIR)

print("X_train:", X_train.shape, "y_train:", y_train.shape)
print("X_val:", X_val.shape, "y_val:", y_val.shape)
print("X_test:", X_test.shape, "y_test:", y_test.shape)

assert X_train.shape[1:] == (12, 1000), "Expected input shape [N, 12, 1000]"
assert X_val.shape[1:] == (12, 1000), "Expected input shape [N, 12, 1000]"
assert X_test.shape[1:] == (12, 1000), "Expected input shape [N, 12, 1000]"
# Out:
# Loading ECG records:   5%|▌         | 913/17418 [09:25<2:50:24,  1.61it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_7423/3362441916.py in <cell line: 0>()
#      32     return X, y
#      33
# ---> 34 X_train, y_train = load_raw_data(train_df, DATA_DIR)
#      35 X_val, y_val = load_raw_data(val_df, DATA_DIR)
#      36 X_test, y_test = load_raw_data(test_df, DATA_DIR)
#
# /tmp/ipykernel_7423/3362441916.py in load_raw_data(metadata_subset, data_dir)
#      13
#      14         try:
# ---> 15             signal, meta = wfdb.rdsamp(str(record_path))
#      16         except Exception as e:
#      17             raise RuntimeError(f"Failed to read {record_path}. Error: {e}")
#
# /usr/local/lib/python3.12/dist-packages/wfdb/io/record.py in rdsamp(record_name, sampfrom, sampto, channels, pn_dir, channel_names, warn_empty, return_res)
#    2344             )
#    2345
# -> 2346     record = rdrecord(
#    2347         record_name=record_name,
#    2348         sampfrom=sampfrom,
#
# /usr/local/lib/python3.12/dist-packages/wfdb/io/record.py in rdrecord(record_name, sampfrom, sampto, channels, physical, pn_dir, m2s, smooth_frames, ignore_skew, return_res, force_channels, channel_names, warn_empty)
#    2134         sig_data = None
#    2135
# -> 2136         record.e_d_signal = _signal._rd_segment(
#    2137             file_name=record.file_name,
#    2138             dir_name=dir_name,
#
# /usr/local/lib/python3.12/dist-packages/wfdb/io/_signal.py in _rd_segment(file_name, dir_name, pn_dir, fmt, n_sig, sig_len, byte_offset, samps_per_frame, skew, init_value, sampfrom, sampto, channels, ignore_skew, no_file, sig_data, return_res)
#    1250     for fn in w_file_name:
#    1251         # Get the list of all signals contained in the dat file
# -> 1252         datsignals = _rd_dat_signals(
#    1253             file_name=fn,
#    1254             dir_name=dir_name,
#
# /usr/local/lib/python3.12/dist-packages/wfdb/io/_signal.py in _rd_dat_signals(file_name, dir_name, pn_dir, fmt, n_sig, sig_len, byte_offset, samps_per_frame, skew, init_value, sampfrom, sampto, no_file, sig_data)
#    1390         )
#    1391     else:
# -> 1392         data_to_read = _rd_dat_file(
#    1393             file_name, dir_name, pn_dir, fmt, start_byte, n_read_samples
#    1394         )
#
# /usr/local/lib/python3.12/dist-packages/wfdb/io/_signal.py in _rd_dat_file(file_name, dir_name, pn_dir, fmt, start_byte, n_samp)
#    1693         with fsspec.open(os.path.join(dir_name, file_name), "rb") as fp:
#    1694             fp.seek(start_byte)
# -> 1695             sig_data = util.fromfile(
#    1696                 fp, dtype=np.dtype(DATA_LOAD_TYPES[fmt]), count=element_count
#    1697             )
#
# /usr/local/lib/python3.12/dist-packages/wfdb/io/util.py in fromfile(fileobj, dtype, count)
#     158             count = (end - start) // dtype.itemsize
#     159         array = np.empty(count, dtype)
# --> 160         size = fileobj.readinto(array.view(np.uint8))
#     161         array.resize(size // dtype.itemsize)
#     162         return array
#
# KeyboardInterrupt:

# %% [markdown]
# ## 9. Train-only Z-score normalization

# %%
# Fit normalization statistics only on training data to avoid data leakage.
# Per-lead mean/std: shape [1, 12, 1]

train_mean = X_train.mean(axis=(0, 2), keepdims=True)
train_std = X_train.std(axis=(0, 2), keepdims=True) + 1e-8

X_train = (X_train - train_mean) / train_std
X_val = (X_val - train_mean) / train_std
X_test = (X_test - train_mean) / train_std

print("Train mean after normalization:", X_train.mean())
print("Train std after normalization:", X_train.std())

np.save(OUTPUT_DIR / "train_mean.npy", train_mean)
np.save(OUTPUT_DIR / "train_std.npy", train_std)
# Out:
# Train mean after normalization: 4.0791156e-07
# Train std after normalization: 1.0216085

# %% [markdown]
# ## 10. PyTorch Dataset and DataLoaders

# %%
class ECGDataset(Dataset):
    def __init__(self, X, y):
        self.X = torch.tensor(X, dtype=torch.float32)
        self.y = torch.tensor(y, dtype=torch.float32)

    def __len__(self):
        return len(self.y)

    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]

BATCH_SIZE = 64

train_loader = DataLoader(
    ECGDataset(X_train, y_train),
    batch_size=BATCH_SIZE,
    shuffle=True,
    num_workers=2 if IN_COLAB else 0,
    pin_memory=True if device.type == "cuda" else False,
)

val_loader = DataLoader(
    ECGDataset(X_val, y_val),
    batch_size=BATCH_SIZE,
    shuffle=False,
    num_workers=2 if IN_COLAB else 0,
    pin_memory=True if device.type == "cuda" else False,
)

test_loader = DataLoader(
    ECGDataset(X_test, y_test),
    batch_size=BATCH_SIZE,
    shuffle=False,
    num_workers=2 if IN_COLAB else 0,
    pin_memory=True if device.type == "cuda" else False,
)

xb, yb = next(iter(train_loader))
print("Batch X:", xb.shape)
print("Batch y:", yb.shape)
# Out:
# Batch X: torch.Size([64, 12, 1000])
# Batch y: torch.Size([64])

# %% [markdown]
# ## 11. Lightweight 1D CNN matching the paper

# %%
class LightweightECGNet(nn.Module):
    def __init__(self, in_channels=12):
        super().__init__()

        self.features = nn.Sequential(
            nn.Conv1d(in_channels, 32, kernel_size=5, stride=1, padding=2),
            nn.BatchNorm1d(32),
            nn.ReLU(inplace=True),
            nn.MaxPool1d(kernel_size=2),

            nn.Conv1d(32, 64, kernel_size=5, stride=1, padding=2),
            nn.BatchNorm1d(64),
            nn.ReLU(inplace=True),
            nn.MaxPool1d(kernel_size=2),

            nn.Conv1d(64, 128, kernel_size=5, stride=1, padding=2),
            nn.BatchNorm1d(128),
            nn.ReLU(inplace=True),
            nn.MaxPool1d(kernel_size=2),
        )

        self.global_pool = nn.AdaptiveAvgPool1d(1)
        self.dropout = nn.Dropout(p=0.5)
        self.classifier = nn.Linear(128, 1)

    def forward(self, x):
        # x shape: [B, 12, 1000]
        x = self.features(x)
        x = self.global_pool(x).squeeze(-1)  # [B, 128]
        x = self.dropout(x)
        logit = self.classifier(x).view(-1)  # [B]
        return logit

model = LightweightECGNet().to(device)

num_params = sum(p.numel() for p in model.parameters())
trainable_params = sum(p.numel() for p in model.parameters() if p.requires_grad)

print(model)
print(f"Total parameters: {num_params:,}")
print(f"Trainable parameters: {trainable_params:,}")

with torch.no_grad():
    dummy = torch.randn(4, 12, 1000).to(device)
    out = model(dummy)
    print("Dummy output shape:", out.shape)
# Out:
# LightweightECGNet(
#   (features): Sequential(
#     (0): Conv1d(12, 32, kernel_size=(5,), stride=(1,), padding=(2,))
#     (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (4): Conv1d(32, 64, kernel_size=(5,), stride=(1,), padding=(2,))
#     (5): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU(inplace=True)
#     (7): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (8): Conv1d(64, 128, kernel_size=(5,), stride=(1,), padding=(2,))
#     (9): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (10): ReLU(inplace=True)
#     (11): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (global_pool): AdaptiveAvgPool1d(output_size=1)
#   (dropout): Dropout(p=0.5, inplace=False)
#   (classifier): Linear(in_features=128, out_features=1, bias=True)
# )
# Total parameters: 53,921
# Trainable parameters: 53,921
# Dummy output shape: torch.Size([4])

# %% [markdown]
# ## 12. Train model and save best validation checkpoint

# %%
criterion = nn.BCEWithLogitsLoss()

# Matches paper setting: Adam with lr=1e-3.
# Weight decay is included here for reproducibility; keep the paper wording aligned with this.
optimizer = optim.Adam(model.parameters(), lr=1e-3, weight_decay=1e-4)

EPOCHS = 5
best_val_loss = float("inf")
best_model_path = OUTPUT_DIR / "best_model.pth"

history = []

for epoch in range(EPOCHS):
    model.train()
    train_loss = 0.0

    for X_batch, y_batch in tqdm(train_loader, desc=f"Epoch {epoch+1}/{EPOCHS} - train"):
        X_batch = X_batch.to(device)
        y_batch = y_batch.float().to(device).view(-1)

        optimizer.zero_grad()
        logits = model(X_batch).view(-1)

        loss = criterion(logits, y_batch)
        loss.backward()
        optimizer.step()

        train_loss += loss.item() * X_batch.size(0)

    train_loss = train_loss / len(train_loader.dataset)

    model.eval()
    val_loss = 0.0

    with torch.no_grad():
        for X_batch, y_batch in tqdm(val_loader, desc=f"Epoch {epoch+1}/{EPOCHS} - val"):
            X_batch = X_batch.to(device)
            y_batch = y_batch.float().to(device).view(-1)

            logits = model(X_batch).view(-1)
            loss = criterion(logits, y_batch)

            val_loss += loss.item() * X_batch.size(0)

    val_loss = val_loss / len(val_loader.dataset)

    row = {
        "epoch": epoch + 1,
        "train_loss": train_loss,
        "val_loss": val_loss,
    }
    history.append(row)

    print(f"Epoch {epoch+1}: Train Loss = {train_loss:.4f}, Val Loss = {val_loss:.4f}")

    if val_loss < best_val_loss:
        best_val_loss = val_loss
        torch.save(model.state_dict(), best_model_path)
        print(f"Best checkpoint saved to {best_model_path}")

history_df = pd.DataFrame(history)
history_df.to_csv(OUTPUT_DIR / "training_history.csv", index=False)
history_df
# Out:
# Epoch 1/5 - train: 100%|██████████| 273/273 [01:30<00:00,  3.00it/s]
# Epoch 1/5 - val: 100%|██████████| 35/35 [00:03<00:00,  9.26it/s]
# Epoch 1: Train Loss = 0.4122, Val Loss = 0.4058
# Best checkpoint saved to /content/drive/MyDrive/ptbxl_mi_project/outputs/best_model.pth
# Epoch 2/5 - train: 100%|██████████| 273/273 [01:30<00:00,  3.02it/s]
# Epoch 2/5 - val: 100%|██████████| 35/35 [00:03<00:00, 10.13it/s]
# Epoch 2: Train Loss = 0.3454, Val Loss = 0.3492
# Best checkpoint saved to /content/drive/MyDrive/ptbxl_mi_project/outputs/best_model.pth
# Epoch 3/5 - train: 100%|██████████| 273/273 [01:31<00:00,  2.97it/s]
# Epoch 3/5 - val: 100%|██████████| 35/35 [00:02<00:00, 12.16it/s]
# Epoch 3: Train Loss = 0.3239, Val Loss = 0.3215
# Best checkpoint saved to /content/drive/MyDrive/ptbxl_mi_project/outputs/best_model.pth
# Epoch 4/5 - train: 100%|██████████| 273/273 [01:30<00:00,  3.01it/s]
# Epoch 4/5 - val: 100%|██████████| 35/35 [00:02<00:00, 13.34it/s]
# Epoch 4: Train Loss = 0.3095, Val Loss = 0.3251
# Epoch 5/5 - train: 100%|██████████| 273/273 [01:31<00:00,  2.99it/s]
# Epoch 5/5 - val: 100%|██████████| 35/35 [00:02<00:00, 13.54it/s]
# Epoch 5: Train Loss = 0.3035, Val Loss = 0.4470
#    epoch  train_loss  val_loss
# 0      1    0.412243  0.405785
# 1      2    0.345425  0.349176
# 2      3    0.323914  0.321524
# 3      4    0.309542  0.325093
# 4      5    0.303454  0.446998

# %% [markdown]
# ## 13. Plot training history

# %%
plt.figure(figsize=(6, 4))
plt.plot(history_df["epoch"], history_df["train_loss"], marker="o", label="Train Loss")
plt.plot(history_df["epoch"], history_df["val_loss"], marker="o", label="Validation Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Training and Validation Loss")
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.savefig(OUTPUT_DIR / "training_validation_loss.png", dpi=300)
plt.show()

# %% [markdown]
# ## 14. Final evaluation on Fold 10 test set

# %%
def collect_probabilities(model, loader, device):
    model.eval()
    all_probs = []
    all_logits = []
    all_labels = []

    with torch.no_grad():
        for X_batch, y_batch in tqdm(loader, desc="Collecting test probabilities"):
            X_batch = X_batch.to(device)
            logits = model(X_batch).view(-1)
            probs = torch.sigmoid(logits)

            all_logits.extend(logits.cpu().numpy())
            all_probs.extend(probs.cpu().numpy())
            all_labels.extend(y_batch.cpu().numpy())

    return (
        np.array(all_logits),
        np.array(all_probs),
        np.array(all_labels).astype(int),
    )

# Load the best validation checkpoint before test evaluation
model.load_state_dict(torch.load(best_model_path, map_location=device))

test_logits, test_probs, test_labels = collect_probabilities(model, test_loader, device)

test_auroc = roc_auc_score(test_labels, test_probs)
test_auprc = average_precision_score(test_labels, test_probs)

print(f"Test AUROC: {test_auroc:.4f}")
print(f"Test AUPRC: {test_auprc:.4f}")

results = {
    "test_auroc": float(test_auroc),
    "test_auprc": float(test_auprc),
    "n_test": int(len(test_labels)),
    "n_positive": int(test_labels.sum()),
    "n_negative": int(len(test_labels) - test_labels.sum()),
}

pd.DataFrame([results]).to_csv(OUTPUT_DIR / "test_results.csv", index=False)
pd.DataFrame([results])
# Out:
# Collecting test probabilities: 100%|██████████| 35/35 [00:04<00:00,  8.73it/s]
# Test AUROC: 0.8939
# Test AUPRC: 0.7789
#    test_auroc  test_auprc  n_test  n_positive  n_negative
# 0    0.893872    0.778938    2198         550        1648

# %% [markdown]
# ## 15. ROC and Precision-Recall curves

# %%
fpr, tpr, _ = roc_curve(test_labels, test_probs)
precision, recall, _ = precision_recall_curve(test_labels, test_probs)

plt.figure(figsize=(6, 4))
plt.plot(fpr, tpr, label=f"AUROC = {test_auroc:.3f}")
plt.plot([0, 1], [0, 1], linestyle="--", label="Random")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve on PTB-XL Fold 10")
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.savefig(OUTPUT_DIR / "roc_curve.png", dpi=300)
plt.show()

plt.figure(figsize=(6, 4))
plt.plot(recall, precision, label=f"AUPRC = {test_auprc:.3f}")
plt.xlabel("Recall")
plt.ylabel("Precision")
plt.title("Precision-Recall Curve on PTB-XL Fold 10")
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.savefig(OUTPUT_DIR / "precision_recall_curve.png", dpi=300)
plt.show()

# %% [markdown]
# ## 16. Optional threshold-dependent metrics at 0.5

# %%
threshold = 0.5
test_pred = (test_probs >= threshold).astype(int)

print("Confusion Matrix:")
print(confusion_matrix(test_labels, test_pred))

print("\nClassification Report:")
print(classification_report(test_labels, test_pred, digits=4))
# Out:
# Confusion Matrix:
# [[1518  130]
#  [ 209  341]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.8790    0.9211    0.8996      1648
#            1     0.7240    0.6200    0.6680       550
#
#     accuracy                         0.8458      2198
#    macro avg     0.8015    0.7706    0.7838      2198
# weighted avg     0.8402    0.8458    0.8416      2198

# %% [markdown]
# ## 17. Optional bootstrap confidence intervals

# %%
def bootstrap_metric_ci(y_true, y_score, metric_fn, n_bootstraps=1000, seed=42, alpha=0.05):
    rng = np.random.default_rng(seed)
    n = len(y_true)
    scores = []

    for _ in tqdm(range(n_bootstraps), desc=f"Bootstrapping {metric_fn.__name__}"):
        indices = rng.integers(0, n, n)
        y_true_sample = y_true[indices]
        y_score_sample = y_score[indices]

        # Skip samples with only one class
        if len(np.unique(y_true_sample)) < 2:
            continue

        scores.append(metric_fn(y_true_sample, y_score_sample))

    scores = np.array(scores)
    lower = np.percentile(scores, 100 * alpha / 2)
    upper = np.percentile(scores, 100 * (1 - alpha / 2))
    mean = np.mean(scores)

    return mean, lower, upper

# Reduce n_bootstraps to 200 if Colab is slow.
N_BOOTSTRAPS = 1000

auroc_mean, auroc_low, auroc_high = bootstrap_metric_ci(
    test_labels, test_probs, roc_auc_score, n_bootstraps=N_BOOTSTRAPS, seed=SEED
)

auprc_mean, auprc_low, auprc_high = bootstrap_metric_ci(
    test_labels, test_probs, average_precision_score, n_bootstraps=N_BOOTSTRAPS, seed=SEED
)

print(f"AUROC mean: {auroc_mean:.4f}, 95% CI: [{auroc_low:.4f}, {auroc_high:.4f}]")
print(f"AUPRC mean: {auprc_mean:.4f}, 95% CI: [{auprc_low:.4f}, {auprc_high:.4f}]")
# Out:
# Bootstrapping roc_auc_score: 100%|██████████| 1000/1000 [00:02<00:00, 380.09it/s]
# Bootstrapping average_precision_score: 100%|██████████| 1000/1000 [00:01<00:00, 645.19it/s]
# AUROC mean: 0.8939, 95% CI: [0.8774, 0.9093]
# AUPRC mean: 0.7787, 95% CI: [0.7461, 0.8079]

# %% [markdown]
# ## 18. Deterministic explanation workflow

# %%
def generate_risk_summary_from_probability(prob):
    if prob >= 0.70:
        risk_tier = "High Risk"
    elif prob >= 0.30:
        risk_tier = "Intermediate Risk"
    else:
        risk_tier = "Low Risk"

    summary = (
        f"Predicted MI probability: {prob:.3f}. "
        f"Risk tier: {risk_tier}. "
        "This ECG-only model does not use troponin biomarkers, symptoms, "
        "patient history, or clinical examination findings. "
        "This output is intended only for research-based decision support "
        "and is not a standalone diagnosis. Formal clinical evaluation is required."
    )

    return risk_tier, summary

def generate_risk_summary_from_logit(logit):
    prob = 1.0 / (1.0 + np.exp(-float(logit)))
    return generate_risk_summary_from_probability(prob)

for i in range(min(5, len(test_probs))):
    risk_tier, summary = generate_risk_summary_from_probability(test_probs[i])
    print("Example:", i)
    print("True label:", int(test_labels[i]))
    print(summary)
    print("-" * 80)
# Out:
# Example: 0
# True label: 0
# Predicted MI probability: 0.047. Risk tier: Low Risk. This ECG-only model does not use troponin biomarkers, symptoms, patient history, or clinical examination findings. This output is intended only for research-based decision support and is not a standalone diagnosis. Formal clinical evaluation is required.
# --------------------------------------------------------------------------------
# Example: 1
# True label: 0
# Predicted MI probability: 0.231. Risk tier: Low Risk. This ECG-only model does not use troponin biomarkers, symptoms, patient history, or clinical examination findings. This output is intended only for research-based decision support and is not a standalone diagnosis. Formal clinical evaluation is required.
# --------------------------------------------------------------------------------
# Example: 2
# True label: 0
# Predicted MI probability: 0.052. Risk tier: Low Risk. This ECG-only model does not use troponin biomarkers, symptoms, patient history, or clinical examination findings. This output is intended only for research-based decision support and is not a standalone diagnosis. Formal clinical evaluation is required.
# --------------------------------------------------------------------------------
# Example: 3
# True label: 0
# Predicted MI probability: 0.008. Risk tier: Low Risk. This ECG-only model does not use troponin biomarkers, symptoms, patient history, or clinical examination findings. This output is intended only for research-based decision support and is not a standalone diagnosis. Formal clinical evaluation is required.
# --------------------------------------------------------------------------------
# Example: 4
# True label: 0
# Predicted MI probability: 0.040. Risk tier: Low Risk. This ECG-only model does not use troponin biomarkers, symptoms, patient history, or clinical examination findings. This output is intended only for research-based decision support and is not a standalone diagnosis. Formal clinical evaluation is required.
# --------------------------------------------------------------------------------

# %% [markdown]
# ## 19. Save example risk summaries

# %%
summary_rows = []

for i in range(min(50, len(test_probs))):
    risk_tier, summary = generate_risk_summary_from_probability(test_probs[i])
    summary_rows.append({
        "index": i,
        "true_label": int(test_labels[i]),
        "logit": float(test_logits[i]),
        "probability": float(test_probs[i]),
        "risk_tier": risk_tier,
        "summary": summary,
    })

summary_df = pd.DataFrame(summary_rows)
summary_df.to_csv(OUTPUT_DIR / "example_risk_summaries.csv", index=False)
summary_df.head()
# Out:
#    index  true_label     logit  probability risk_tier  \
# 0      0           0 -3.018661     0.046590  Low Risk
# 1      1           0 -1.201241     0.231255  Low Risk
# 2      2           0 -2.897577     0.052273  Low Risk
# 3      3           0 -4.852945     0.007745  Low Risk
# 4      4           0 -3.190806     0.039513  Low Risk
#
#                                              summary
# 0  Predicted MI probability: 0.047. Risk tier: Lo...
# 1  Predicted MI probability: 0.231. Risk tier: Lo...
# 2  Predicted MI probability: 0.052. Risk tier: Lo...
# 3  Predicted MI probability: 0.008. Risk tier: Lo...
# 4  Predicted MI probability: 0.040. Risk tier: Lo...

# %% [markdown]
# ## 20. Paper consistency checklist
#
# After running the notebook, confirm these items before submitting the paper:
#
# 1. The data split is:
#    - Train: folds 1–8
#    - Validation: fold 9
#    - Test: fold 10
# 2. The input tensor shape is `[B, 12, 1000]`.
# 3. Normalization statistics were fitted only on the training set.
# 4. The model outputs raw logits.
# 5. `BCEWithLogitsLoss` receives raw logits, not sigmoid probabilities.
# 6. The best validation checkpoint is loaded before Fold-10 testing.
# 7. AUROC and AUPRC in the paper match the printed notebook values.
# 8. The explanation workflow uses thresholds 0.30 and 0.70.
# 9. The paper does not claim standalone diagnosis or clinical deployment.
# 10. The output directory contains:
#     - `training_history.csv`
#     - `test_results.csv`
#     - `roc_curve.png`
#     - `precision_recall_curve.png`
#     - `example_risk_summaries.csv`
